# %%
import os
import numpy as np
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet import preprocess_input
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Initialize the pre-trained MobileNet model without the top classification layer
model = MobileNet(weights='imagenet', include_top=False, input_shape=(224, 224, 3), pooling='avg')

# Function to extract features from an image
def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)  # Preprocess for MobileNet
    features = model.predict(img_array)
    return features.flatten()

# Directory paths
hamburger_train_dir = '../data/food11/train/hamburger'
hamburger_test_dir = '../data/food11/test/hamburger'

# Collect all image paths in the pizza folders
image_paths = [os.path.join(hamburger_train_dir, fname) for fname in os.listdir(hamburger_train_dir)]
image_paths += [os.path.join(hamburger_test_dir, fname) for fname in os.listdir(hamburger_test_dir)]

# Extract features for all images
features = []
for img_path in image_paths:
    try:
        features.append(extract_features(img_path, model))
    except Exception as e:
        print(f"Error processing image {img_path}: {e}")

features = np.array(features)
print(f"Extracted features for {len(features)} images")
# Out:
# Extracted features for 911 images

# %%
from sklearn.cluster import KMeans

# Number of clusters (choose based on expected subcategories, e.g., 3 types of pizza)
num_clusters = 8

# Perform K-Means clustering
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(features)

# Get cluster labels for each image
cluster_labels = kmeans.labels_

# Print the cluster label for each image
for img_path, label in zip(image_paths, cluster_labels):
    print(f"{img_path} assigned to cluster {label}")
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ../data/food11/train/hamburger\1007277.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1009426.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1010136.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1010140.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1010695.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1013830.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1017874.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1028639.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1029228.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1031616.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1035486.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1036215.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1036785.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1038553.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1041547.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1041748.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1041751.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1042117.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1049005.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1053407.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1057407.jpg assigned to cluster 6
# ../data/food11/train/hamburger\1061270.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1065477.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1071442.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1084567.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1084912.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1086335.jpg assigned to cluster 6
# ../data/food11/train/hamburger\1101890.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1104146.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1105370.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1122669.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1126075.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1133388.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1144233.jpg assigned to cluster 1
# ../data/food11/train/hamburger\1151417.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1170104.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1175157.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1175221.jpg assigned to cluster 6
# ../data/food11/train/hamburger\1175284.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1175364.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1175395.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1177971.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1181766.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1192222.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1202261.jpg assigned to cluster 6
# ../data/food11/train/hamburger\1208447.jpg assigned to cluster 6
# ../data/food11/train/hamburger\1210060.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1213037.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1225832.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1228951.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1230241.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1234438.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1237509.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1239003.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1245594.jpg assigned to cluster 1
# ../data/food11/train/hamburger\1249041.jpg assigned to cluster 7
# ../data/food11/train/hamburger\1253144.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1253448.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1255149.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1260356.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1276246.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1286359.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1289156.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1290485.jpg assigned to cluster 1
# ../data/food11/train/hamburger\1301947.jpg assigned to cluster 1
# ../data/food11/train/hamburger\1302578.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1303545.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1307906.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1309089.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1317285.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1317619.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1326608.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1327199.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1334884.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1335771.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1337536.jpg assigned to cluster 1
# ../data/food11/train/hamburger\1343040.jpg assigned to cluster 7
# ../data/food11/train/hamburger\1350012.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1351742.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1356688.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1357604.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1380338.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1381751.jpg assigned to cluster 6
# ../data/food11/train/hamburger\1385479.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1392659.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1398841.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1403548.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1404731.jpg assigned to cluster 6
# ../data/food11/train/hamburger\1417023.jpg assigned to cluster 1
# ../data/food11/train/hamburger\1425173.jpg assigned to cluster 6
# ../data/food11/train/hamburger\1447114.jpg assigned to cluster 7
# ../data/food11/train/hamburger\1447695.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1452537.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1455172.jpg assigned to cluster 7
# ../data/food11/train/hamburger\1459413.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1459453.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1473146.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1474492.jpg assigned to cluster 1
# ../data/food11/train/hamburger\1478950.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1488723.jpg assigned to cluster 7
# ../data/food11/train/hamburger\1489337.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1489753.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1489783.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1492254.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1500893.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1510284.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1512098.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1512586.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1514911.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1520708.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1525376.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1526341.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1535073.jpg assigned to cluster 7
# ../data/food11/train/hamburger\1538992.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1540758.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1543118.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1545728.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1546566.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1548268.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1552080.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1553214.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1565439.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1566310.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1567823.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1570733.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1583543.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1584018.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1591393.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1594058.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1596452.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1597001.jpg assigned to cluster 6
# ../data/food11/train/hamburger\1597561.jpg assigned to cluster 7
# ../data/food11/train/hamburger\1601449.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1626383.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1634763.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1635356.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1636096.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1643371.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1643851.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1645528.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1654528.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1669585.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1670180.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1679008.jpg assigned to cluster 7
# ../data/food11/train/hamburger\1693358.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1709710.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1718036.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1724647.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1733250.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1741383.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1747465.jpg assigned to cluster 7
# ../data/food11/train/hamburger\1756519.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1757576.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1768219.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1770793.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1772548.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1781176.jpg assigned to cluster 7
# ../data/food11/train/hamburger\1802721.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1804091.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1812972.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1816650.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1818289.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1818719.jpg assigned to cluster 1
# ../data/food11/train/hamburger\1821268.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1822493.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1823305.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1828545.jpg assigned to cluster 7
# ../data/food11/train/hamburger\1831555.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1833096.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1838179.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1839233.jpg assigned to cluster 1
# ../data/food11/train/hamburger\1840084.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1847289.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1847757.jpg assigned to cluster 6
# ../data/food11/train/hamburger\1852483.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1854382.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1864131.jpg assigned to cluster 6
# ../data/food11/train/hamburger\1864786.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1879189.jpg assigned to cluster 6
# ../data/food11/train/hamburger\1888361.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1889072.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1890101.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1897946.jpg assigned to cluster 6
# ../data/food11/train/hamburger\1903326.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1906193.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1908105.jpg assigned to cluster 7
# ../data/food11/train/hamburger\1909271.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1922963.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1923024.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1923125.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1928916.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1935602.jpg assigned to cluster 0
# ../data/food11/train/hamburger\1957899.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1959744.jpg assigned to cluster 1
# ../data/food11/train/hamburger\1960715.jpg assigned to cluster 3
# ../data/food11/train/hamburger\1964319.jpg assigned to cluster 7
# ../data/food11/train/hamburger\1969928.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1970489.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1973158.jpg assigned to cluster 1
# ../data/food11/train/hamburger\1974530.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1979079.jpg assigned to cluster 4
# ../data/food11/train/hamburger\1983089.jpg assigned to cluster 5
# ../data/food11/train/hamburger\1985087.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1991820.jpg assigned to cluster 2
# ../data/food11/train/hamburger\1992893.jpg assigned to cluster 7
# ../data/food11/train/hamburger\1999677.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2000097.jpg assigned to cluster 0
# ../data/food11/train/hamburger\2005380.jpg assigned to cluster 0
# ../data/food11/train/hamburger\2007244.jpg assigned to cluster 6
# ../data/food11/train/hamburger\2009324.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2014421.jpg assigned to cluster 0
# ../data/food11/train/hamburger\2025737.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2028843.jpg assigned to cluster 0
# ../data/food11/train/hamburger\2034553.jpg assigned to cluster 0
# ../data/food11/train/hamburger\2035320.jpg assigned to cluster 1
# ../data/food11/train/hamburger\2062556.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2063044.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2089191.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2090357.jpg assigned to cluster 6
# ../data/food11/train/hamburger\2100733.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2100953.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2100991.jpg assigned to cluster 7
# ../data/food11/train/hamburger\2103375.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2103408.jpg assigned to cluster 5
# ../data/food11/train/hamburger\2107358.jpg assigned to cluster 0
# ../data/food11/train/hamburger\2111010.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2114471.jpg assigned to cluster 5
# ../data/food11/train/hamburger\2117694.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2119225.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2125562.jpg assigned to cluster 0
# ../data/food11/train/hamburger\212746.jpg assigned to cluster 7
# ../data/food11/train/hamburger\2128914.jpg assigned to cluster 1
# ../data/food11/train/hamburger\2129527.jpg assigned to cluster 7
# ../data/food11/train/hamburger\2130925.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2131711.jpg assigned to cluster 7
# ../data/food11/train/hamburger\2135938.jpg assigned to cluster 1
# ../data/food11/train/hamburger\2142633.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2145273.jpg assigned to cluster 5
# ../data/food11/train/hamburger\214601.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2148281.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2148997.jpg assigned to cluster 2
# ../data/food11/train/hamburger\215037.jpg assigned to cluster 5
# ../data/food11/train/hamburger\215349.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2154348.jpg assigned to cluster 7
# ../data/food11/train/hamburger\2157483.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2165484.jpg assigned to cluster 2
# ../data/food11/train/hamburger\216853.jpg assigned to cluster 5
# ../data/food11/train/hamburger\2177068.jpg assigned to cluster 7
# ../data/food11/train/hamburger\2178047.jpg assigned to cluster 4
# ../data/food11/train/hamburger\217855.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2182615.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2184165.jpg assigned to cluster 6
# ../data/food11/train/hamburger\2188106.jpg assigned to cluster 5
# ../data/food11/train/hamburger\2188393.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2189229.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2200084.jpg assigned to cluster 1
# ../data/food11/train/hamburger\2201071.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2207445.jpg assigned to cluster 0
# ../data/food11/train/hamburger\2212320.jpg assigned to cluster 0
# ../data/food11/train/hamburger\2213149.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2214528.jpg assigned to cluster 7
# ../data/food11/train/hamburger\2217236.jpg assigned to cluster 2
# ../data/food11/train/hamburger\221845.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2218533.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2219841.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2222741.jpg assigned to cluster 5
# ../data/food11/train/hamburger\2232379.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2237356.jpg assigned to cluster 5
# ../data/food11/train/hamburger\2240462.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2241307.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2248152.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2248694.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2250663.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2252809.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2256750.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2257914.jpg assigned to cluster 0
# ../data/food11/train/hamburger\2264276.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2268998.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2274013.jpg assigned to cluster 1
# ../data/food11/train/hamburger\2277205.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2278946.jpg assigned to cluster 5
# ../data/food11/train/hamburger\2303809.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2311474.jpg assigned to cluster 6
# ../data/food11/train/hamburger\2312480.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2313612.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2316148.jpg assigned to cluster 3
# ../data/food11/train/hamburger\231857.jpg assigned to cluster 5
# ../data/food11/train/hamburger\2319376.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2330829.jpg assigned to cluster 5
# ../data/food11/train/hamburger\2332261.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2341674.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2352227.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2361390.jpg assigned to cluster 7
# ../data/food11/train/hamburger\2361393.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2363407.jpg assigned to cluster 2
# ../data/food11/train/hamburger\236924.jpg assigned to cluster 0
# ../data/food11/train/hamburger\2372320.jpg assigned to cluster 0
# ../data/food11/train/hamburger\2385388.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2386519.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2390722.jpg assigned to cluster 4
# ../data/food11/train/hamburger\239086.jpg assigned to cluster 3
# ../data/food11/train/hamburger\239309.jpg assigned to cluster 7
# ../data/food11/train/hamburger\2405850.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2406075.jpg assigned to cluster 6
# ../data/food11/train/hamburger\2410291.jpg assigned to cluster 5
# ../data/food11/train/hamburger\2410431.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2411538.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2417159.jpg assigned to cluster 0
# ../data/food11/train/hamburger\2419243.jpg assigned to cluster 6
# ../data/food11/train/hamburger\242083.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2426514.jpg assigned to cluster 0
# ../data/food11/train/hamburger\242929.jpg assigned to cluster 2
# ../data/food11/train/hamburger\243204.jpg assigned to cluster 2
# ../data/food11/train/hamburger\243709.jpg assigned to cluster 7
# ../data/food11/train/hamburger\2437718.jpg assigned to cluster 1
# ../data/food11/train/hamburger\244216.jpg assigned to cluster 2
# ../data/food11/train/hamburger\245244.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2460012.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2466948.jpg assigned to cluster 1
# ../data/food11/train/hamburger\247640.jpg assigned to cluster 0
# ../data/food11/train/hamburger\2477264.jpg assigned to cluster 7
# ../data/food11/train/hamburger\2480925.jpg assigned to cluster 0
# ../data/food11/train/hamburger\248136.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2482999.jpg assigned to cluster 6
# ../data/food11/train/hamburger\2495221.jpg assigned to cluster 1
# ../data/food11/train/hamburger\2498283.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2503712.jpg assigned to cluster 6
# ../data/food11/train/hamburger\250782.jpg assigned to cluster 1
# ../data/food11/train/hamburger\2508539.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2514512.jpg assigned to cluster 0
# ../data/food11/train/hamburger\2521595.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2522403.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2534877.jpg assigned to cluster 7
# ../data/food11/train/hamburger\2537883.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2537940.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2551984.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2560683.jpg assigned to cluster 1
# ../data/food11/train/hamburger\2562323.jpg assigned to cluster 5
# ../data/food11/train/hamburger\256294.jpg assigned to cluster 1
# ../data/food11/train/hamburger\256317.jpg assigned to cluster 7
# ../data/food11/train/hamburger\2564531.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2574916.jpg assigned to cluster 7
# ../data/food11/train/hamburger\258288.jpg assigned to cluster 0
# ../data/food11/train/hamburger\258503.jpg assigned to cluster 7
# ../data/food11/train/hamburger\2591266.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2591354.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2599548.jpg assigned to cluster 0
# ../data/food11/train/hamburger\2609270.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2612278.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2612664.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2619287.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2622394.jpg assigned to cluster 1
# ../data/food11/train/hamburger\2622458.jpg assigned to cluster 1
# ../data/food11/train/hamburger\2623364.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2626189.jpg assigned to cluster 6
# ../data/food11/train/hamburger\2630526.jpg assigned to cluster 6
# ../data/food11/train/hamburger\2634081.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2662814.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2663947.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2665487.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2668437.jpg assigned to cluster 5
# ../data/food11/train/hamburger\2671820.jpg assigned to cluster 7
# ../data/food11/train/hamburger\2674001.jpg assigned to cluster 0
# ../data/food11/train/hamburger\2686914.jpg assigned to cluster 6
# ../data/food11/train/hamburger\2687426.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2705807.jpg assigned to cluster 5
# ../data/food11/train/hamburger\2710550.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2710786.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2711405.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2715888.jpg assigned to cluster 7
# ../data/food11/train/hamburger\271916.jpg assigned to cluster 5
# ../data/food11/train/hamburger\272642.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2726558.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2738245.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2745577.jpg assigned to cluster 6
# ../data/food11/train/hamburger\2745917.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2754513.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2756964.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2762170.jpg assigned to cluster 1
# ../data/food11/train/hamburger\2766731.jpg assigned to cluster 7
# ../data/food11/train/hamburger\2771605.jpg assigned to cluster 3
# ../data/food11/train/hamburger\277584.jpg assigned to cluster 2
# ../data/food11/train/hamburger\279510.jpg assigned to cluster 0
# ../data/food11/train/hamburger\2797268.jpg assigned to cluster 4
# ../data/food11/train/hamburger\279729.jpg assigned to cluster 1
# ../data/food11/train/hamburger\2808308.jpg assigned to cluster 2
# ../data/food11/train/hamburger\281725.jpg assigned to cluster 0
# ../data/food11/train/hamburger\281733.jpg assigned to cluster 5
# ../data/food11/train/hamburger\2825993.jpg assigned to cluster 1
# ../data/food11/train/hamburger\2826072.jpg assigned to cluster 0
# ../data/food11/train/hamburger\2829795.jpg assigned to cluster 0
# ../data/food11/train/hamburger\283514.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2836127.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2836933.jpg assigned to cluster 0
# ../data/food11/train/hamburger\2838015.jpg assigned to cluster 5
# ../data/food11/train/hamburger\285069.jpg assigned to cluster 7
# ../data/food11/train/hamburger\285384.jpg assigned to cluster 7
# ../data/food11/train/hamburger\286323.jpg assigned to cluster 6
# ../data/food11/train/hamburger\2874704.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2879938.jpg assigned to cluster 1
# ../data/food11/train/hamburger\2884546.jpg assigned to cluster 7
# ../data/food11/train/hamburger\2891622.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2894838.jpg assigned to cluster 0
# ../data/food11/train/hamburger\2897464.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2899066.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2901664.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2902992.jpg assigned to cluster 7
# ../data/food11/train/hamburger\290587.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2906568.jpg assigned to cluster 2
# ../data/food11/train/hamburger\2923292.jpg assigned to cluster 2
# ../data/food11/train/hamburger\292599.jpg assigned to cluster 2
# ../data/food11/train/hamburger\292737.jpg assigned to cluster 5
# ../data/food11/train/hamburger\2928946.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2930558.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2935045.jpg assigned to cluster 1
# ../data/food11/train/hamburger\2945142.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2945814.jpg assigned to cluster 6
# ../data/food11/train/hamburger\294644.jpg assigned to cluster 5
# ../data/food11/train/hamburger\2961000.jpg assigned to cluster 3
# ../data/food11/train/hamburger\2962236.jpg assigned to cluster 5
# ../data/food11/train/hamburger\2970771.jpg assigned to cluster 6
# ../data/food11/train/hamburger\2975573.jpg assigned to cluster 4
# ../data/food11/train/hamburger\2977639.jpg assigned to cluster 1
# ../data/food11/train/hamburger\298239.jpg assigned to cluster 1
# ../data/food11/train/hamburger\2982689.jpg assigned to cluster 6
# ../data/food11/train/hamburger\2984854.jpg assigned to cluster 1
# ../data/food11/train/hamburger\2988095.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3008087.jpg assigned to cluster 0
# ../data/food11/train/hamburger\301264.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3019166.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3020130.jpg assigned to cluster 2
# ../data/food11/train/hamburger\302613.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3028569.jpg assigned to cluster 0
# ../data/food11/train/hamburger\3030255.jpg assigned to cluster 1
# ../data/food11/train/hamburger\3031490.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3037400.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3037447.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3043581.jpg assigned to cluster 6
# ../data/food11/train/hamburger\3057786.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3062381.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3069250.jpg assigned to cluster 6
# ../data/food11/train/hamburger\3083927.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3088660.jpg assigned to cluster 0
# ../data/food11/train/hamburger\309049.jpg assigned to cluster 1
# ../data/food11/train/hamburger\3090530.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3101158.jpg assigned to cluster 2
# ../data/food11/train/hamburger\310724.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3125905.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3127729.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3131777.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3131908.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3132952.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3140245.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3140576.jpg assigned to cluster 1
# ../data/food11/train/hamburger\314426.jpg assigned to cluster 3
# ../data/food11/train/hamburger\315121.jpg assigned to cluster 1
# ../data/food11/train/hamburger\3153937.jpg assigned to cluster 6
# ../data/food11/train/hamburger\3155346.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3156127.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3156598.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3156785.jpg assigned to cluster 7
# ../data/food11/train/hamburger\315876.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3160193.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3162373.jpg assigned to cluster 6
# ../data/food11/train/hamburger\3166759.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3167157.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3168485.jpg assigned to cluster 7
# ../data/food11/train/hamburger\3172516.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3182852.jpg assigned to cluster 0
# ../data/food11/train/hamburger\3199592.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3213507.jpg assigned to cluster 5
# ../data/food11/train/hamburger\3215406.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3218659.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3219029.jpg assigned to cluster 0
# ../data/food11/train/hamburger\3220288.jpg assigned to cluster 3
# ../data/food11/train/hamburger\322228.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3228181.jpg assigned to cluster 7
# ../data/food11/train/hamburger\3231173.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3243138.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3244630.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3274673.jpg assigned to cluster 6
# ../data/food11/train/hamburger\3278767.jpg assigned to cluster 5
# ../data/food11/train/hamburger\3282635.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3283071.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3283283.jpg assigned to cluster 7
# ../data/food11/train/hamburger\3287766.jpg assigned to cluster 7
# ../data/food11/train/hamburger\3289634.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3295316.jpg assigned to cluster 0
# ../data/food11/train/hamburger\3305010.jpg assigned to cluster 6
# ../data/food11/train/hamburger\330566.jpg assigned to cluster 1
# ../data/food11/train/hamburger\330628.jpg assigned to cluster 7
# ../data/food11/train/hamburger\3308102.jpg assigned to cluster 6
# ../data/food11/train/hamburger\3308293.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3309917.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3312172.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3317888.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3328593.jpg assigned to cluster 7
# ../data/food11/train/hamburger\333517.jpg assigned to cluster 5
# ../data/food11/train/hamburger\3336850.jpg assigned to cluster 3
# ../data/food11/train/hamburger\334442.jpg assigned to cluster 0
# ../data/food11/train/hamburger\3346138.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3347896.jpg assigned to cluster 1
# ../data/food11/train/hamburger\3353691.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3354260.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3365675.jpg assigned to cluster 3
# ../data/food11/train/hamburger\337374.jpg assigned to cluster 7
# ../data/food11/train/hamburger\3384314.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3385808.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3391627.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3394148.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3397863.jpg assigned to cluster 7
# ../data/food11/train/hamburger\339829.jpg assigned to cluster 1
# ../data/food11/train/hamburger\339960.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3402120.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3406531.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3409351.jpg assigned to cluster 4
# ../data/food11/train/hamburger\340982.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3410764.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3413347.jpg assigned to cluster 6
# ../data/food11/train/hamburger\342538.jpg assigned to cluster 5
# ../data/food11/train/hamburger\3432262.jpg assigned to cluster 0
# ../data/food11/train/hamburger\3433981.jpg assigned to cluster 5
# ../data/food11/train/hamburger\3435863.jpg assigned to cluster 1
# ../data/food11/train/hamburger\3438060.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3442375.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3450907.jpg assigned to cluster 6
# ../data/food11/train/hamburger\345291.jpg assigned to cluster 6
# ../data/food11/train/hamburger\3452947.jpg assigned to cluster 5
# ../data/food11/train/hamburger\3463634.jpg assigned to cluster 5
# ../data/food11/train/hamburger\3470026.jpg assigned to cluster 1
# ../data/food11/train/hamburger\3474160.jpg assigned to cluster 0
# ../data/food11/train/hamburger\3479742.jpg assigned to cluster 5
# ../data/food11/train/hamburger\3483897.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3486079.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3486853.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3488531.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3490968.jpg assigned to cluster 5
# ../data/food11/train/hamburger\3502852.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3502862.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3508112.jpg assigned to cluster 6
# ../data/food11/train/hamburger\350854.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3510148.jpg assigned to cluster 0
# ../data/food11/train/hamburger\3514547.jpg assigned to cluster 3
# ../data/food11/train/hamburger\351506.jpg assigned to cluster 0
# ../data/food11/train/hamburger\352061.jpg assigned to cluster 3
# ../data/food11/train/hamburger\352840.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3530013.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3530076.jpg assigned to cluster 6
# ../data/food11/train/hamburger\3530266.jpg assigned to cluster 3
# ../data/food11/train/hamburger\353298.jpg assigned to cluster 1
# ../data/food11/train/hamburger\3536773.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3538912.jpg assigned to cluster 0
# ../data/food11/train/hamburger\3543840.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3549095.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3550428.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3555912.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3563379.jpg assigned to cluster 7
# ../data/food11/train/hamburger\3568995.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3570133.jpg assigned to cluster 6
# ../data/food11/train/hamburger\3570287.jpg assigned to cluster 5
# ../data/food11/train/hamburger\3577815.jpg assigned to cluster 6
# ../data/food11/train/hamburger\3577939.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3581748.jpg assigned to cluster 0
# ../data/food11/train/hamburger\3583066.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3594693.jpg assigned to cluster 4
# ../data/food11/train/hamburger\360082.jpg assigned to cluster 5
# ../data/food11/train/hamburger\3606132.jpg assigned to cluster 6
# ../data/food11/train/hamburger\3606601.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3616027.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3634090.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3637949.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3640020.jpg assigned to cluster 6
# ../data/food11/train/hamburger\3643079.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3643495.jpg assigned to cluster 7
# ../data/food11/train/hamburger\3647386.jpg assigned to cluster 7
# ../data/food11/train/hamburger\3652790.jpg assigned to cluster 6
# ../data/food11/train/hamburger\3655355.jpg assigned to cluster 7
# ../data/food11/train/hamburger\3655547.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3665956.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3667950.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3670065.jpg assigned to cluster 0
# ../data/food11/train/hamburger\3671365.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3673642.jpg assigned to cluster 5
# ../data/food11/train/hamburger\3673989.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3677215.jpg assigned to cluster 5
# ../data/food11/train/hamburger\3681763.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3685652.jpg assigned to cluster 0
# ../data/food11/train/hamburger\3692315.jpg assigned to cluster 0
# ../data/food11/train/hamburger\3697145.jpg assigned to cluster 7
# ../data/food11/train/hamburger\3700554.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3702789.jpg assigned to cluster 5
# ../data/food11/train/hamburger\370752.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3712135.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3713125.jpg assigned to cluster 4
# ../data/food11/train/hamburger\371830.jpg assigned to cluster 7
# ../data/food11/train/hamburger\3718488.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3722584.jpg assigned to cluster 5
# ../data/food11/train/hamburger\3726429.jpg assigned to cluster 5
# ../data/food11/train/hamburger\3728099.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3728987.jpg assigned to cluster 0
# ../data/food11/train/hamburger\3732779.jpg assigned to cluster 6
# ../data/food11/train/hamburger\3736455.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3737888.jpg assigned to cluster 1
# ../data/food11/train/hamburger\3741248.jpg assigned to cluster 4
# ../data/food11/train/hamburger\374344.jpg assigned to cluster 5
# ../data/food11/train/hamburger\3743605.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3745227.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3750804.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3753321.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3766010.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3768429.jpg assigned to cluster 7
# ../data/food11/train/hamburger\3769905.jpg assigned to cluster 3
# ../data/food11/train/hamburger\376995.jpg assigned to cluster 4
# ../data/food11/train/hamburger\3771719.jpg assigned to cluster 6
# ../data/food11/train/hamburger\3771888.jpg assigned to cluster 4
# ../data/food11/train/hamburger\378487.jpg assigned to cluster 1
# ../data/food11/train/hamburger\3790333.jpg assigned to cluster 6
# ../data/food11/train/hamburger\3791190.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3796218.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3805259.jpg assigned to cluster 1
# ../data/food11/train/hamburger\3805565.jpg assigned to cluster 0
# ../data/food11/train/hamburger\3807630.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3807701.jpg assigned to cluster 7
# ../data/food11/train/hamburger\3811038.jpg assigned to cluster 5
# ../data/food11/train/hamburger\381322.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3816451.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3821078.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3822189.jpg assigned to cluster 5
# ../data/food11/train/hamburger\382691.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3830375.jpg assigned to cluster 1
# ../data/food11/train/hamburger\385296.jpg assigned to cluster 5
# ../data/food11/train/hamburger\3866252.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3866906.jpg assigned to cluster 5
# ../data/food11/train/hamburger\3867148.jpg assigned to cluster 1
# ../data/food11/train/hamburger\3878886.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3880113.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3894442.jpg assigned to cluster 5
# ../data/food11/train/hamburger\3900340.jpg assigned to cluster 1
# ../data/food11/train/hamburger\3901132.jpg assigned to cluster 2
# ../data/food11/train/hamburger\3905260.jpg assigned to cluster 3
# ../data/food11/train/hamburger\3912017.jpg assigned to cluster 0
# ../data/food11/train/hamburger\3916139.jpg assigned to cluster 0
# ../data/food11/train/hamburger\3919964.jpg assigned to cluster 4
# ../data/food11/train/hamburger\392846.jpg assigned to cluster 3
# ../data/food11/train/hamburger\396083.jpg assigned to cluster 4
# ../data/food11/train/hamburger\398340.jpg assigned to cluster 0
# ../data/food11/train/hamburger\402200.jpg assigned to cluster 4
# ../data/food11/train/hamburger\402245.jpg assigned to cluster 5
# ../data/food11/train/hamburger\406359.jpg assigned to cluster 5
# ../data/food11/train/hamburger\406390.jpg assigned to cluster 5
# ../data/food11/train/hamburger\410334.jpg assigned to cluster 7
# ../data/food11/train/hamburger\413222.jpg assigned to cluster 7
# ../data/food11/train/hamburger\415105.jpg assigned to cluster 0
# ../data/food11/train/hamburger\415662.jpg assigned to cluster 3
# ../data/food11/train/hamburger\417861.jpg assigned to cluster 4
# ../data/food11/train/hamburger\418104.jpg assigned to cluster 6
# ../data/food11/train/hamburger\419342.jpg assigned to cluster 4
# ../data/food11/train/hamburger\419902.jpg assigned to cluster 2
# ../data/food11/train/hamburger\423924.jpg assigned to cluster 2
# ../data/food11/train/hamburger\424637.jpg assigned to cluster 4
# ../data/food11/train/hamburger\428710.jpg assigned to cluster 3
# ../data/food11/train/hamburger\438537.jpg assigned to cluster 2
# ../data/food11/train/hamburger\440560.jpg assigned to cluster 3
# ../data/food11/train/hamburger\440931.jpg assigned to cluster 6
# ../data/food11/train/hamburger\442330.jpg assigned to cluster 7
# ../data/food11/train/hamburger\443349.jpg assigned to cluster 3
# ../data/food11/train/hamburger\446192.jpg assigned to cluster 3
# ../data/food11/train/hamburger\447012.jpg assigned to cluster 4
# ../data/food11/train/hamburger\448484.jpg assigned to cluster 3
# ../data/food11/train/hamburger\450282.jpg assigned to cluster 5
# ../data/food11/train/hamburger\450434.jpg assigned to cluster 5
# ../data/food11/train/hamburger\460108.jpg assigned to cluster 4
# ../data/food11/train/hamburger\468712.jpg assigned to cluster 3
# ../data/food11/train/hamburger\473236.jpg assigned to cluster 0
# ../data/food11/train/hamburger\474373.jpg assigned to cluster 2
# ../data/food11/train/hamburger\476337.jpg assigned to cluster 3
# ../data/food11/train/hamburger\477600.jpg assigned to cluster 7
# ../data/food11/train/hamburger\484022.jpg assigned to cluster 1
# ../data/food11/train/hamburger\486402.jpg assigned to cluster 4
# ../data/food11/train/hamburger\489986.jpg assigned to cluster 3
# ../data/food11/train/hamburger\492903.jpg assigned to cluster 4
# ../data/food11/train/hamburger\499370.jpg assigned to cluster 5
# ../data/food11/train/hamburger\499437.jpg assigned to cluster 4
# ../data/food11/train/hamburger\503145.jpg assigned to cluster 3
# ../data/food11/train/hamburger\509480.jpg assigned to cluster 1
# ../data/food11/train/hamburger\510448.jpg assigned to cluster 6
# ../data/food11/train/hamburger\520715.jpg assigned to cluster 2
# ../data/food11/train/hamburger\526567.jpg assigned to cluster 3
# ../data/food11/train/hamburger\526683.jpg assigned to cluster 7
# ../data/food11/train/hamburger\526726.jpg assigned to cluster 3
# ../data/food11/train/hamburger\528494.jpg assigned to cluster 2
# ../data/food11/train/hamburger\529449.jpg assigned to cluster 1
# ../data/food11/train/hamburger\535451.jpg assigned to cluster 0
# ../data/food11/train/hamburger\539998.jpg assigned to cluster 5
# ../data/food11/train/hamburger\541358.jpg assigned to cluster 0
# ../data/food11/train/hamburger\543722.jpg assigned to cluster 6
# ../data/food11/train/hamburger\552647.jpg assigned to cluster 3
# ../data/food11/train/hamburger\554363.jpg assigned to cluster 6
# ../data/food11/train/hamburger\554810.jpg assigned to cluster 2
# ../data/food11/train/hamburger\555211.jpg assigned to cluster 7
# ../data/food11/train/hamburger\557542.jpg assigned to cluster 0
# ../data/food11/train/hamburger\560478.jpg assigned to cluster 0
# ../data/food11/train/hamburger\561431.jpg assigned to cluster 2
# ../data/food11/train/hamburger\561979.jpg assigned to cluster 2
# ../data/food11/train/hamburger\564651.jpg assigned to cluster 7
# ../data/food11/train/hamburger\568518.jpg assigned to cluster 0
# ../data/food11/train/hamburger\571953.jpg assigned to cluster 0
# ../data/food11/train/hamburger\576270.jpg assigned to cluster 7
# ../data/food11/train/hamburger\576807.jpg assigned to cluster 0
# ../data/food11/train/hamburger\577312.jpg assigned to cluster 3
# ../data/food11/train/hamburger\577673.jpg assigned to cluster 7
# ../data/food11/train/hamburger\577684.jpg assigned to cluster 4
# ../data/food11/train/hamburger\579852.jpg assigned to cluster 5
# ../data/food11/train/hamburger\580186.jpg assigned to cluster 1
# ../data/food11/train/hamburger\582274.jpg assigned to cluster 2
# ../data/food11/train/hamburger\583603.jpg assigned to cluster 5
# ../data/food11/train/hamburger\585430.jpg assigned to cluster 4
# ../data/food11/train/hamburger\585443.jpg assigned to cluster 0
# ../data/food11/train/hamburger\587018.jpg assigned to cluster 2
# ../data/food11/train/hamburger\588037.jpg assigned to cluster 2
# ../data/food11/train/hamburger\591221.jpg assigned to cluster 3
# ../data/food11/train/hamburger\592885.jpg assigned to cluster 2
# ../data/food11/train/hamburger\593030.jpg assigned to cluster 4
# ../data/food11/train/hamburger\595963.jpg assigned to cluster 4
# ../data/food11/train/hamburger\598436.jpg assigned to cluster 1
# ../data/food11/train/hamburger\601386.jpg assigned to cluster 5
# ../data/food11/train/hamburger\603807.jpg assigned to cluster 1
# ../data/food11/train/hamburger\604162.jpg assigned to cluster 2
# ../data/food11/train/hamburger\604483.jpg assigned to cluster 3
# ../data/food11/train/hamburger\607735.jpg assigned to cluster 6
# ../data/food11/train/hamburger\607907.jpg assigned to cluster 3
# ../data/food11/train/hamburger\608198.jpg assigned to cluster 1
# ../data/food11/train/hamburger\611133.jpg assigned to cluster 0
# ../data/food11/train/hamburger\613983.jpg assigned to cluster 0
# ../data/food11/train/hamburger\615546.jpg assigned to cluster 3
# ../data/food11/train/hamburger\618159.jpg assigned to cluster 4
# ../data/food11/train/hamburger\620037.jpg assigned to cluster 6
# ../data/food11/train/hamburger\620632.jpg assigned to cluster 1
# ../data/food11/train/hamburger\624407.jpg assigned to cluster 5
# ../data/food11/train/hamburger\624980.jpg assigned to cluster 5
# ../data/food11/train/hamburger\629010.jpg assigned to cluster 1
# ../data/food11/train/hamburger\629268.jpg assigned to cluster 1
# ../data/food11/train/hamburger\634096.jpg assigned to cluster 3
# ../data/food11/train/hamburger\637917.jpg assigned to cluster 4
# ../data/food11/train/hamburger\639957.jpg assigned to cluster 3
# ../data/food11/train/hamburger\639977.jpg assigned to cluster 6
# ../data/food11/train/hamburger\640204.jpg assigned to cluster 3
# ../data/food11/train/hamburger\642418.jpg assigned to cluster 7
# ../data/food11/train/hamburger\643450.jpg assigned to cluster 1
# ../data/food11/train/hamburger\650755.jpg assigned to cluster 5
# ../data/food11/train/hamburger\656458.jpg assigned to cluster 6
# ../data/food11/train/hamburger\657820.jpg assigned to cluster 0
# ../data/food11/train/hamburger\658208.jpg assigned to cluster 7
# ../data/food11/train/hamburger\669487.jpg assigned to cluster 3
# ../data/food11/train/hamburger\686342.jpg assigned to cluster 4
# ../data/food11/train/hamburger\697480.jpg assigned to cluster 4
# ../data/food11/train/hamburger\697639.jpg assigned to cluster 3
# ../data/food11/train/hamburger\698451.jpg assigned to cluster 5
# ../data/food11/train/hamburger\699176.jpg assigned to cluster 7
# ../data/food11/train/hamburger\699700.jpg assigned to cluster 4
# ../data/food11/train/hamburger\699829.jpg assigned to cluster 7
# ../data/food11/train/hamburger\700343.jpg assigned to cluster 7
# ../data/food11/train/hamburger\703677.jpg assigned to cluster 3
# ../data/food11/train/hamburger\708454.jpg assigned to cluster 4
# ../data/food11/train/hamburger\716829.jpg assigned to cluster 4
# ../data/food11/train/hamburger\719858.jpg assigned to cluster 4
# ../data/food11/train/hamburger\724367.jpg assigned to cluster 2
# ../data/food11/train/hamburger\730040.jpg assigned to cluster 2
# ../data/food11/train/hamburger\732473.jpg assigned to cluster 4
# ../data/food11/train/hamburger\734458.jpg assigned to cluster 0
# ../data/food11/train/hamburger\740621.jpg assigned to cluster 3
# ../data/food11/train/hamburger\745392.jpg assigned to cluster 2
# ../data/food11/train/hamburger\747666.jpg assigned to cluster 3
# ../data/food11/train/hamburger\750597.jpg assigned to cluster 0
# ../data/food11/train/hamburger\762602.jpg assigned to cluster 4
# ../data/food11/train/hamburger\764175.jpg assigned to cluster 0
# ../data/food11/train/hamburger\775003.jpg assigned to cluster 1
# ../data/food11/train/hamburger\779936.jpg assigned to cluster 6
# ../data/food11/train/hamburger\782170.jpg assigned to cluster 5
# ../data/food11/train/hamburger\782295.jpg assigned to cluster 1
# ../data/food11/train/hamburger\787142.jpg assigned to cluster 0
# ../data/food11/train/hamburger\799334.jpg assigned to cluster 0
# ../data/food11/train/hamburger\800876.jpg assigned to cluster 4
# ../data/food11/train/hamburger\804047.jpg assigned to cluster 4
# ../data/food11/train/hamburger\806392.jpg assigned to cluster 3
# ../data/food11/train/hamburger\806915.jpg assigned to cluster 3
# ../data/food11/train/hamburger\809137.jpg assigned to cluster 3
# ../data/food11/train/hamburger\810199.jpg assigned to cluster 7
# ../data/food11/train/hamburger\811344.jpg assigned to cluster 4
# ../data/food11/train/hamburger\816775.jpg assigned to cluster 4
# ../data/food11/train/hamburger\821346.jpg assigned to cluster 1
# ../data/food11/train/hamburger\825243.jpg assigned to cluster 6
# ../data/food11/train/hamburger\825337.jpg assigned to cluster 1
# ../data/food11/train/hamburger\828367.jpg assigned to cluster 4
# ../data/food11/train/hamburger\839963.jpg assigned to cluster 3
# ../data/food11/train/hamburger\840018.jpg assigned to cluster 0
# ../data/food11/train/hamburger\842229.jpg assigned to cluster 2
# ../data/food11/train/hamburger\845305.jpg assigned to cluster 4
# ../data/food11/train/hamburger\846950.jpg assigned to cluster 5
# ../data/food11/train/hamburger\847016.jpg assigned to cluster 7
# ../data/food11/train/hamburger\861844.jpg assigned to cluster 0
# ../data/food11/train/hamburger\862025.jpg assigned to cluster 0
# ../data/food11/train/hamburger\862582.jpg assigned to cluster 1
# ../data/food11/train/hamburger\868903.jpg assigned to cluster 6
# ../data/food11/train/hamburger\873705.jpg assigned to cluster 3
# ../data/food11/train/hamburger\878103.jpg assigned to cluster 7
# ../data/food11/train/hamburger\878925.jpg assigned to cluster 4
# ../data/food11/train/hamburger\879355.jpg assigned to cluster 2
# ../data/food11/train/hamburger\883801.jpg assigned to cluster 5
# ../data/food11/train/hamburger\892777.jpg assigned to cluster 4
# ../data/food11/train/hamburger\898642.jpg assigned to cluster 3
# ../data/food11/train/hamburger\903277.jpg assigned to cluster 1
# ../data/food11/train/hamburger\909950.jpg assigned to cluster 3
# ../data/food11/train/hamburger\917931.jpg assigned to cluster 3
# ../data/food11/train/hamburger\922386.jpg assigned to cluster 1
# ../data/food11/train/hamburger\923384.jpg assigned to cluster 4
# ../data/food11/train/hamburger\930645.jpg assigned to cluster 4
# ../data/food11/train/hamburger\939444.jpg assigned to cluster 4
# ../data/food11/train/hamburger\950766.jpg assigned to cluster 1
# ../data/food11/train/hamburger\960781.jpg assigned to cluster 6
# ../data/food11/train/hamburger\966137.jpg assigned to cluster 3
# ../data/food11/train/hamburger\966618.jpg assigned to cluster 4
# ../data/food11/train/hamburger\973733.jpg assigned to cluster 3
# ../data/food11/train/hamburger\976482.jpg assigned to cluster 4
# ../data/food11/train/hamburger\985020.jpg assigned to cluster 2
# ../data/food11/train/hamburger\986085.jpg assigned to cluster 5
# ../data/food11/train/hamburger\986604.jpg assigned to cluster 7
# ../data/food11/train/hamburger\988443.jpg assigned to cluster 2
# ../data/food11/train/hamburger\990601.jpg assigned to cluster 3
# ../data/food11/train/hamburger\991372.jpg assigned to cluster 5
# ../data/food11/train/hamburger\992374.jpg assigned to cluster 0
# ../data/food11/train/hamburger\992429.jpg assigned to cluster 4
# ../data/food11/train/hamburger\992590.jpg assigned to cluster 4
# ../data/food11/test/hamburger\100057.jpg assigned to cluster 3
# ../data/food11/test/hamburger\100517.jpg assigned to cluster 3
# ../data/food11/test/hamburger\100719.jpg assigned to cluster 2
# ../data/food11/test/hamburger\100930.jpg assigned to cluster 7
# ../data/food11/test/hamburger\102005.jpg assigned to cluster 1
# ../data/food11/test/hamburger\103716.jpg assigned to cluster 5
# ../data/food11/test/hamburger\107320.jpg assigned to cluster 3
# ../data/food11/test/hamburger\109961.jpg assigned to cluster 1
# ../data/food11/test/hamburger\110991.jpg assigned to cluster 5
# ../data/food11/test/hamburger\112314.jpg assigned to cluster 3
# ../data/food11/test/hamburger\116741.jpg assigned to cluster 0
# ../data/food11/test/hamburger\117020.jpg assigned to cluster 0
# ../data/food11/test/hamburger\118484.jpg assigned to cluster 2
# ../data/food11/test/hamburger\129939.jpg assigned to cluster 2
# ../data/food11/test/hamburger\130598.jpg assigned to cluster 1
# ../data/food11/test/hamburger\134819.jpg assigned to cluster 3
# ../data/food11/test/hamburger\13641.jpg assigned to cluster 3
# ../data/food11/test/hamburger\137432.jpg assigned to cluster 4
# ../data/food11/test/hamburger\138330.jpg assigned to cluster 3
# ../data/food11/test/hamburger\13915.jpg assigned to cluster 0
# ../data/food11/test/hamburger\139558.jpg assigned to cluster 0
# ../data/food11/test/hamburger\145378.jpg assigned to cluster 7
# ../data/food11/test/hamburger\14657.jpg assigned to cluster 4
# ../data/food11/test/hamburger\153931.jpg assigned to cluster 5
# ../data/food11/test/hamburger\155496.jpg assigned to cluster 5
# ../data/food11/test/hamburger\155594.jpg assigned to cluster 5
# ../data/food11/test/hamburger\157688.jpg assigned to cluster 1
# ../data/food11/test/hamburger\159304.jpg assigned to cluster 5
# ../data/food11/test/hamburger\162789.jpg assigned to cluster 5
# ../data/food11/test/hamburger\163637.jpg assigned to cluster 4
# ../data/food11/test/hamburger\166566.jpg assigned to cluster 1
# ../data/food11/test/hamburger\166940.jpg assigned to cluster 5
# ../data/food11/test/hamburger\169479.jpg assigned to cluster 4
# ../data/food11/test/hamburger\170292.jpg assigned to cluster 3
# ../data/food11/test/hamburger\172005.jpg assigned to cluster 3
# ../data/food11/test/hamburger\177861.jpg assigned to cluster 4
# ../data/food11/test/hamburger\178840.jpg assigned to cluster 3
# ../data/food11/test/hamburger\179593.jpg assigned to cluster 3
# ../data/food11/test/hamburger\184751.jpg assigned to cluster 1
# ../data/food11/test/hamburger\184955.jpg assigned to cluster 1
# ../data/food11/test/hamburger\204552.jpg assigned to cluster 2
# ../data/food11/test/hamburger\209001.jpg assigned to cluster 2
# ../data/food11/test/hamburger\22093.jpg assigned to cluster 3
# ../data/food11/test/hamburger\23454.jpg assigned to cluster 0
# ../data/food11/test/hamburger\24753.jpg assigned to cluster 5
# ../data/food11/test/hamburger\30012.jpg assigned to cluster 5
# ../data/food11/test/hamburger\42335.jpg assigned to cluster 2
# ../data/food11/test/hamburger\45064.jpg assigned to cluster 2
# ../data/food11/test/hamburger\45547.jpg assigned to cluster 7
# ../data/food11/test/hamburger\47595.jpg assigned to cluster 1
# ../data/food11/test/hamburger\50638.jpg assigned to cluster 2
# ../data/food11/test/hamburger\54507.jpg assigned to cluster 0
# ../data/food11/test/hamburger\57610.jpg assigned to cluster 7
# ../data/food11/test/hamburger\58431.jpg assigned to cluster 4
# ../data/food11/test/hamburger\60794.jpg assigned to cluster 2
# ../data/food11/test/hamburger\6432.jpg assigned to cluster 5
# ../data/food11/test/hamburger\65141.jpg assigned to cluster 1
# ../data/food11/test/hamburger\68979.jpg assigned to cluster 2
# ../data/food11/test/hamburger\70019.jpg assigned to cluster 6
# ../data/food11/test/hamburger\72111.jpg assigned to cluster 6
# ../data/food11/test/hamburger\72266.jpg assigned to cluster 2
# ../data/food11/test/hamburger\73340.jpg assigned to cluster 2
# ../data/food11/test/hamburger\73783.jpg assigned to cluster 6
# ../data/food11/test/hamburger\75550.jpg assigned to cluster 2
# ../data/food11/test/hamburger\76858.jpg assigned to cluster 5
# ../data/food11/test/hamburger\79711.jpg assigned to cluster 1
# ../data/food11/test/hamburger\81707.jpg assigned to cluster 4
# ../data/food11/test/hamburger\81732.jpg assigned to cluster 2
# ../data/food11/test/hamburger\81813.jpg assigned to cluster 2
# ../data/food11/test/hamburger\82314.jpg assigned to cluster 2
# ../data/food11/test/hamburger\83196.jpg assigned to cluster 6
# ../data/food11/test/hamburger\85915.jpg assigned to cluster 2
# ../data/food11/test/hamburger\90115.jpg assigned to cluster 3
# ../data/food11/test/hamburger\91566.jpg assigned to cluster 7
# ../data/food11/test/hamburger\91602.jpg assigned to cluster 3
# ../data/food11/test/hamburger\91710.jpg assigned to cluster 2
# ../data/food11/test/hamburger\91789.jpg assigned to cluster 2
# ../data/food11/test/hamburger\97917.jpg assigned to cluster 3

# %%
import shutil

# Create directories for each cluster (subcategories)
for i in range(num_clusters):
    train_subdir = os.path.join(hamburger_train_dir, f"cluster_{i}")
    test_subdir = os.path.join(hamburger_test_dir, f"cluster_{i}")
    os.makedirs(train_subdir, exist_ok=True)
    os.makedirs(test_subdir, exist_ok=True)

# Move images to subdirectories based on cluster labels
for img_path, label in zip(image_paths, cluster_labels):
    if 'train' in img_path:
        shutil.move(img_path, os.path.join(hamburger_train_dir, f"cluster_{label}", os.path.basename(img_path)))
    elif 'test' in img_path:
        shutil.move(img_path, os.path.join(hamburger_test_dir, f"cluster_{label}", os.path.basename(img_path)))

print("Images moved to their respective cluster directories.")
# Out:
# Images moved to their respective cluster directories.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model

# Fine-grained apple_pie classification
hamburger_train_gen = ImageDataGenerator(rescale=1./255)
hamburger_test_gen = ImageDataGenerator(rescale=1./255)

hamburger_train_generator = hamburger_train_gen.flow_from_directory(
    hamburger_train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

hamburger_test_generator = hamburger_test_gen.flow_from_directory(
    hamburger_test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

# Use the same base model (MobileNet)
base_model_hamburger = MobileNet(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model layers
for layer in base_model_hamburger.layers:
    layer.trainable = False

# Add custom layers for apple_pie classification
x_hamburger = base_model_hamburger.output
x_hamburger = GlobalAveragePooling2D()(x_hamburger)
x_hamburger = Dense(512, activation='relu')(x_hamburger)
hamburger_predictions = Dense(num_clusters, activation='softmax')(x_hamburger)

# Create and compile the model
hamburger_model = Model(inputs=base_model_hamburger.input, outputs=hamburger_predictions)
hamburger_model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# Train the fine-grained apple_pie classification model
hamburger_model.fit(
    hamburger_train_generator,
    steps_per_epoch=hamburger_train_generator.samples // 32,
    validation_data=hamburger_test_generator,
    validation_steps=hamburger_test_generator.samples // 32,
    epochs=30
)

# Save the model
hamburger_model.save('fine_grained_hamburger_classifier.h5')
# Out:
# Found 833 images belonging to 8 classes.
# Found 78 images belonging to 8 classes.
# Epoch 1/30
# 26/26 [==============================] - 8s 262ms/step - loss: 1.9445 - accuracy: 0.2984 - val_loss: 1.4565 - val_accuracy: 0.4844
# Epoch 2/30
# 26/26 [==============================] - 7s 252ms/step - loss: 1.2425 - accuracy: 0.6117 - val_loss: 1.1177 - val_accuracy: 0.6250
# Epoch 3/30
# 26/26 [==============================] - 6s 247ms/step - loss: 0.9251 - accuracy: 0.7366 - val_loss: 0.8686 - val_accuracy: 0.7344
# Epoch 4/30
# 26/26 [==============================] - 7s 249ms/step - loss: 0.7041 - accuracy: 0.8190 - val_loss: 0.7350 - val_accuracy: 0.7812
# Epoch 5/30
# 26/26 [==============================] - 6s 248ms/step - loss: 0.5636 - accuracy: 0.8789 - val_loss: 0.6203 - val_accuracy: 0.8594
# Epoch 6/30
# 26/26 [==============================] - 6s 247ms/step - loss: 0.4592 - accuracy: 0.9251 - val_loss: 0.6175 - val_accuracy: 0.8438
# Epoch 7/30
# 26/26 [==============================] - 7s 249ms/step - loss: 0.3931 - accuracy: 0.9388 - val_loss: 0.5841 - val_accuracy: 0.7812
# Epoch 8/30
# 26/26 [==============================] - 7s 249ms/step - loss: 0.3571 - accuracy: 0.9376 - val_loss: 0.5925 - val_accuracy: 0.7344
# Epoch 9/30
# 26/26 [==============================] - 7s 248ms/step - loss: 0.2965 - accuracy: 0.9588 - val_loss: 0.4573 - val_accuracy: 0.8906
# Epoch 10/30
# 26/26 [==============================] - 7s 249ms/step - loss: 0.2548 - accuracy: 0.9788 - val_loss: 0.4833 - val_accuracy: 0.8281
# Epoch 11/30
# 26/26 [==============================] - 6s 249ms/step - loss: 0.2256 - accuracy: 0.9775 - val_loss: 0.4556 - val_accuracy: 0.7969
# Epoch 12/30
# 26/26 [==============================] - 7s 272ms/step - loss: 0.1974 - accuracy: 0.9925 - val_loss: 0.4657 - val_accuracy: 0.8594
# Epoch 13/30
# 26/26 [==============================] - 7s 268ms/step - loss: 0.1789 - accuracy: 0.9950 - val_loss: 0.4338 - val_accuracy: 0.8281
# Epoch 14/30
# 26/26 [==============================] - 7s 269ms/step - loss: 0.1596 - accuracy: 0.9938 - val_loss: 0.3746 - val_accuracy: 0.8906
# Epoch 15/30
# 26/26 [==============================] - 7s 275ms/step - loss: 0.1426 - accuracy: 0.9988 - val_loss: 0.4260 - val_accuracy: 0.8438
# Epoch 16/30
# 26/26 [==============================] - 7s 274ms/step - loss: 0.1337 - accuracy: 0.9975 - val_loss: 0.3866 - val_accuracy: 0.8750
# Epoch 17/30
# 26/26 [==============================] - 7s 269ms/step - loss: 0.1224 - accuracy: 0.9975 - val_loss: 0.4197 - val_accuracy: 0.8438
# Epoch 18/30
# 26/26 [==============================] - 7s 267ms/step - loss: 0.1081 - accuracy: 1.0000 - val_loss: 0.4222 - val_accuracy: 0.8281
# Epoch 19/30
# 26/26 [==============================] - 7s 267ms/step - loss: 0.0968 - accuracy: 1.0000 - val_loss: 0.3700 - val_accuracy: 0.8594
# Epoch 20/30
# 26/26 [==============================] - 7s 267ms/step - loss: 0.0917 - accuracy: 1.0000 - val_loss: 0.3804 - val_accuracy: 0.8594
# Epoch 21/30
# 26/26 [==============================] - 7s 269ms/step - loss: 0.0825 - accuracy: 1.0000 - val_loss: 0.3417 - val_accuracy: 0.8906
# Epoch 22/30
# 26/26 [==============================] - 7s 271ms/step - loss: 0.0786 - accuracy: 1.0000 - val_loss: 0.3472 - val_accuracy: 0.8750
# Epoch 23/30
# 26/26 [==============================] - 7s 267ms/step - loss: 0.0708 - accuracy: 1.0000 - val_loss: 0.3578 - val_accuracy: 0.8750
# Epoch 24/30
# 26/26 [==============================] - 7s 269ms/step - loss: 0.0662 - accuracy: 1.0000 - val_loss: 0.3581 - val_accuracy: 0.8594
# Epoch 25/30
# 26/26 [==============================] - 7s 267ms/step - loss: 0.0617 - accuracy: 1.0000 - val_loss: 0.3708 - val_accuracy: 0.8594
# Epoch 26/30
# 26/26 [==============================] - 7s 267ms/step - loss: 0.0590 - accuracy: 1.0000 - val_loss: 0.3445 - val_accuracy: 0.8594
# Epoch 27/30
# 26/26 [==============================] - 7s 268ms/step - loss: 0.0548 - accuracy: 1.0000 - val_loss: 0.3746 - val_accuracy: 0.8594
# Epoch 28/30
# 26/26 [==============================] - 7s 269ms/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 0.3276 - val_accuracy: 0.8594
# Epoch 29/30
# 26/26 [==============================] - 7s 269ms/step - loss: 0.0477 - accuracy: 1.0000 - val_loss: 0.3906 - val_accuracy: 0.8594
# Epoch 30/30
# 26/26 [==============================] - 7s 269ms/step - loss: 0.0448 - accuracy: 1.0000 - val_loss: 0.3203 - val_accuracy: 0.9062
